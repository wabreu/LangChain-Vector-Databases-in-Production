# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /Users/w/anaconda3/lib/python3.11/site-packages (4.32.1)
# Requirement already satisfied: filelock in /Users/w/anaconda3/lib/python3.11/site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /Users/w/anaconda3/lib/python3.11/site-packages (from transformers) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in /Users/w/anaconda3/lib/python3.11/site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/w/anaconda3/lib/python3.11/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/w/anaconda3/lib/python3.11/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/w/anaconda3/lib/python3.11/site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in /Users/w/anaconda3/lib/python3.11/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/w/anaconda3/lib/python3.11/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/w/anaconda3/lib/python3.11/site-packages (from transformers) (0.3.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/w/anaconda3/lib/python3.11/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /Users/w/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/w/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/w/anaconda3/lib/python3.11/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/w/anaconda3/lib/python3.11/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/w/anaconda3/lib/python3.11/site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/w/anaconda3/lib/python3.11/site-packages (from requests->transformers) (2023.7.22)

# %%
from transformers import AutoTokenizer 

tokenizer = AutoTokenizer.from_pretrained("gpt2")

print(tokenizer.vocab)
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# Downloading config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# {'ĠCOM': 9440, 'ĠGlass': 12158, 'ĠNAT': 10149, 'Ġrim': 20254, 'ĠJS': 26755, 'Ġcongen': 41174, 'ORTS': 33002, 'Ġperpetrator': 33599, 'Ġobnoxious': 43283, 'itech': 45396, 'ĠSERV': 42887, 'foo': 21943, 'econom': 13926, 'Ġpeas': 22589, 'ĠRaqqa': 30391, 'picture': 34053, 'Ġsetbacks': 43235, 'hall': 18323, 'ĠScore': 15178, 'risome': 47400, 'ãĥ³ãĤ¸': 45823, 'OC': 4503, 'Ġprovoking': 45625, 'AST': 11262, 'Ġtirelessly': 47905, 'Ġtotality': 44861, 'ĠDMCA': 49648, 'Ġcalc': 42302, 'Ġ1987': 12923, 'ats': 1381, 'Ġproxies': 41775, 'KEN': 43959, 'gr': 2164, 'ĠMER': 34482, 'ĠPalestin': 6336, 'ĠCampus': 25005, 'ĠRape': 35286, 'ĠHis': 2399, 'cause': 25587, 'ĠIndependent': 13362, 'Ġentit': 26189, 'ĠÂ®': 38852, 'Ġrapper': 25670, 'ary': 560, 'opened': 26350, 'zhou': 38536, 'Ġnan': 15709, 'ĠCuriosity': 39736, 'bernatorial': 43660, 'Ī': 230, 'Ġsmuggling': 29529, 'ĠMit': 11707, 'Ġnet': 2010, 'stated': 21989, 'Ġcommunicating': 22889, 'Ġtemples': 27081, 'ĠPhil': 4543, 'Ġgrouped': 32824, 'aby': 3930, 'ĠAmpl': 44074, 'Ġannouncer': 49032, 'Ġ123': 17031, 'Ġmonetary': 15331, 'Ġoriented': 25921, 'ĠGallery': 12917, 'hra': 45056, 'Ġbass': 12702, 'ried': 2228, 'asel': 48038, 'Sw': 10462, 'Ïĥ': 38392, 'Ġdivided': 9086, 'ISON': 39960, 'id': 312, 'Ġtaxable': 25069, 'Ġ:(': 36147, 'Ġplatform': 3859, 'Ġrequiring': 10616, 'Ġunravel': 30282, 'attribute': 42348, 'ĠMR': 17242, 'ä¸': 10310, 'Ġrecalled': 12433, 'Ġtracking': 9646, 'Ġsavage': 27303, 'ched': 1740, 'Putin': 17060, 'ĠChallenge': 13879, '+)': 28988, 'ĠCAD': 37292, 'Ġwww': 7324, 'Ġusur': 39954, 'mens': 45535, '748': 48246, 'uchin': 43416, 'Ġvoc': 12776, 'Ġhammer': 15554, 'Ġcontest': 8414, 'ĠAnch': 29253, 'ĠRandall': 29799, 'Lost': 31042, 'Ġseconds': 4201, 'edy': 4716, 'ocations': 20968, 'ĠTucker': 25951, 'Ġincom': 15501, 'Ġdeity': 26462, 'ĠGrimm': 27145, 'Se': 4653, 'MENTS': 28957, 'Ġtimet': 35732, 'ĠReload': 37653, 'Ġ1906': 40538, 'Counter': 31694, 'ailed': 6255, 'code': 8189, 'Ġbargain': 22803, 'Factory': 22810, 'FILE': 25664, 'Ġfascist': 28342, 'Ġdigest': 16274, 'ĠSell': 25688, 'Ġ850': 30607, 'ĠOro': 31770, 'ĠGeological': 34246, 'liners': 34380, 'Ġmidway': 37720, 'Ġshar': 13986, 'ĠHomeland': 17444, 'ĠPsycho': 38955, 'Ġblister': 40770, 'ĠTorres': 27663, 'Ġobsess': 24961, 'Ġinefficient': 30904, 'Tur': 17483, 'ĠAuction': 36071, 'Ġlogged': 18832, '________________________________________________________________': 27193, 'auto': 23736, 'arton': 41328, 'ĠCurry': 20920, 'Ġbundles': 36344, 'Ġprolifer': 19873, 'ilial': 43475, 'ĠVald': 38552, 'ĠSut': 45220, 'Amid': 43541, '940': 46899, 'ĠCorporate': 26040, 'KNOWN': 44706, 'Host': 17932, 'ĠSOU': 30065, 'Ġtenure': 17081, 'healthy': 22796, '\\-': 41441, 'Ġexcessive': 13181, 'Ġsteroid': 40762, 'elia': 25418, 'Ġkios': 46739, 'Ġwraps': 27521, 'suit': 6063, 'ourning': 31626, 'ĠJapan': 2869, 'ĠLoud': 41520, 'ĠZak': 32605, 'nuts': 31381, 'Ġderail': 33749, 'Ġscripts': 14750, 'Ġtotalitarian': 34524, 'Ġillusions': 34739, 'wine': 39002, 'ĠLavrov': 43991, 'cycles': 32503, 'ĠBliss': 44044, 'ĠGREEN': 47606, 'Ġpeaks': 25740, 'ĠDwight': 29902, 'rompt': 45700, 'ãĤ½': 47559, "'": 6, 'pped': 1496, 'yn': 2047, 'Ġvigorous': 31543, 'Ġaccess': 1895, 'Ġhum': 1311, 'itect': 5712, 'oln': 10875, 'ĠMagazine': 11175, 'ĠAPP': 43504, 'ĠOMG': 43821, 'andestine': 35887, 'Hours': 39792, 'ilight': 15512, 'Ġforeskin': 49877, 'Ġgruesome': 34557, 'Ġcorrespond': 6053, 'Hell': 28254, 'ansson': 44038, 'avis': 23401, 'Ġdirectors': 13445, 'Ultimately': 27212, '1990': 19891, 'Ġrepentance': 45893, '209': 22567, 'Ġthumb': 15683, 'Ġupright': 24826, 'ĠMcCann': 48309, 'Ġthrowing': 9644, 'ĠREL': 29749, 'ĠToo': 14190, 'Beast': 41490, 'Avg': 48997, 'Ġlich': 43049, 'Ġshortly': 8972, 'Ġvanilla': 16858, 'ĠPowell': 19675, 'Ġpassage': 10066, 'Ġnegotiator': 49194, 'Ġhomosexuals': 35655, 'ioch': 41097, 'edd': 6048, 'ĠSNP': 25632, 'ĠRapids': 27466, 'Ġcontamination': 22733, 'Ġ./': 24457, 'Ġstrong': 1913, 'rain': 3201, 'Reddit': 22367, 'Ġpreview': 12714, 'Ġheadphone': 36769, 'IER': 38311, 'ĠKidd': 40144, 'Ġ44': 5846, 'humans': 40205, ...

# %%
token_ids = tokenizer.encode("This is a sample text to test the tokenizer")

print( "Tolens: ", tokenizer.convert_ids_to_tokens(token_ids) )
print( "Token IDs: ", token_ids)
# Out:
# Tolens:  ['This', 'Ġis', 'Ġa', 'Ġsample', 'Ġtext', 'Ġto', 'Ġtest', 'Ġthe', 'Ġtoken', 'izer']
# Token IDs:  [1212, 318, 257, 6291, 2420, 284, 1332, 262, 11241, 7509]
